# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
from IPython.display import display
import numpy as np
import os

# %% [markdown]
# #### Loading and Viewing CSV from input folder

# %%
df = pd.read_csv("C:/Users/AmarachiOny/Desktop/DFD_Projects/Python/Compass_ESO_Data/input/Compass_Data_1.csv")
display(df.sample(15))
# Out:
#                 Alarm DateTime  Dispatch Total Response Time  \
# 20436                      NaN                           NaN
# 3442   2025-09-20 12:16:15.000                         387.0
# 6801                       NaN                           NaN
# 27198  2025-09-02 18:58:36.000                         377.0
# 28689  2025-10-27 22:16:27.000                         442.0
# 37964  2026-04-20 11:53:03.000                         308.0
# 47102  2025-10-23 08:41:44.000                         321.0
# 57261  2025-08-30 15:39:47.000                         326.0
# 44077                      NaN                           NaN
# 13108                      NaN                           NaN
# 48718                      NaN                           NaN
# 48764  2026-04-26 04:31:40.000                         293.0
# 38312  2025-12-29 00:27:28.000                         292.0
# 54942  2025-09-27 16:15:02.000                         281.0
# 41763  2026-04-27 13:38:51.000                         511.0
#
#        EMS Apparatus Count Incident Number  \
# 20436                  NaN             NaN
# 3442                   0.0         2530118
# 6801                   NaN             NaN
# 27198                  0.0         2528088
# 28689                  0.0         2534536
# 37964                  0.0         2612264
# 47102                  0.0         2533937
# 57261                  0.0         2527743
# 44077                  NaN             NaN
# 13108                  NaN             NaN
# 48718                  NaN             NaN
# 48764                  0.0         2612895
# 38312                  0.0         2541567
# 54942                  0.0         2530932
# 41763                  0.0         2613049
#
#                                            Incident Type Incident Type Group  \
# 20436                                                NaN                 NaN
# 3442                     Medical assist, assist EMS crew  300 - Rescue & EMS
# 6801                                                 NaN                 NaN
# 27198                    Medical assist, assist EMS crew  300 - Rescue & EMS
# 28689                    Medical assist, assist EMS crew  300 - Rescue & EMS
# 37964                    Medical assist, assist EMS crew  300 - Rescue & EMS
# 47102   EMS call, excluding vehicle accident with injury  300 - Rescue & EMS
# 57261   EMS call, excluding vehicle accident with injury  300 - Rescue & EMS
# 44077                                                NaN                 NaN
# 13108                                                NaN                 NaN
# 48718                                                NaN                 NaN
# 48764                    Medical assist, assist EMS crew  300 - Rescue & EMS
# 38312                             Passenger vehicle fire          100 - Fire
# 54942  Smoke detector activation, no fire - unintenti...   700 - False Alarm
# 41763                    Medical assist, assist EMS crew  300 - Rescue & EMS
#
#         Latitude  Longitude    Shift      Station  \
# 20436        NaN        NaN      NaN          NaN
# 3442   35.941746 -78.894821  B Shift  CAD Beat 04
# 6801         NaN        NaN      NaN          NaN
# 27198  35.988026 -78.919968  C Shift  CAD Beat 05
# 28689  35.972744 -78.907883  B Shift  CAD Beat 04
# 37964  35.958542 -78.976532  A Shift        FS 11
# 47102  36.059761 -78.931396  C Shift  CAD Beat 07
# 57261  35.949585 -78.877113  B Shift  CAD Beat 04
# 44077        NaN        NaN      NaN          NaN
# 13108        NaN        NaN      NaN          NaN
# 48718        NaN        NaN      NaN          NaN
# 48764  35.894821 -78.848915  B Shift        FS 19
# 38312  35.983788 -78.863144  B Shift  CAD Beat 03
# 54942  35.941544 -78.785347  B Shift  CAD Beat 17
# 41763  35.883312 -78.887909  B Shift        FS 12
#
#        Suppression Apparatus Count  Total On Scene Time  \
# 20436                          NaN                  NaN
# 3442                           1.0                949.0
# 6801                           NaN                  NaN
# 27198                          1.0                902.0
# 28689                          1.0                 73.0
# 37964                          2.0                394.0
# 47102                          1.0                724.0
# 57261                          2.0               1710.0
# 44077                          NaN                  NaN
# 13108                          NaN                  NaN
# 48718                          NaN                  NaN
# 48764                          1.0                846.0
# 38312                          7.0              19540.0
# 54942                          2.0                215.0
# 41763                          1.0                280.0
#
#        Total Time Alarm to Last Unit Cleared                Apparatus Type
# 20436                                    NaN      Other apparatus/resource
# 3442                                  1331.0  Medical & rescue unit, other
# 6801                                     NaN                        Engine
# 27198                                 1272.0                        Engine
# 28689                                  504.0  Medical & rescue unit, other
# 37964                                  685.0               Truck or aerial
# 47102                                 1015.0  Medical & rescue unit, other
# 57261                                 2031.0  Medical & rescue unit, other
# 44077                                    NaN  Medical & rescue unit, other
# 13108                                    NaN             Chief officer car
# 48718                                    NaN                        Engine
# 48764                                 1128.0                        Engine
# 38312                                19740.0                        Engine
# 54942                                  427.0               Truck or aerial
# 41763                                  774.0                        Engine

# %%
print(df.columns.tolist())
# Out:
# ['Alarm DateTime', 'Dispatch Total Response Time', 'EMS Apparatus Count', 'Incident Number', 'Incident Type', 'Incident Type Group', 'Latitude', 'Longitude', 'Shift', 'Station', 'Suppression Apparatus Count', 'Total On Scene Time', 'Total Time Alarm to Last Unit Cleared', 'Apparatus Type']

# %% [markdown]
# #### Splitting Alarm Date Time to Alarm Date & Alarm Time

# %%
# Ensuring datetime type
df["Alarm DateTime"] = pd.to_datetime(df["Alarm DateTime"])

# Splitting into separate columns
df["Alarm Date"] = df["Alarm DateTime"].dt.date.astype(str)   # YYYY-MM-DD
df["Alarm Time"] = df["Alarm DateTime"].dt.time.astype(str)   # HH:MM:SS

# Dropping original column
df = df.drop(columns=["Alarm DateTime"])

# Moving new columns to the front
cols = ["Alarm Date", "Alarm Time"] + [c for c in df.columns if c not in ["Alarm Date", "Alarm Time"]]
df = df[cols]

display(df.sample(5))
# Out:
#        Alarm Date Alarm Time  Dispatch Total Response Time  \
# 51745  2025-08-03   11:33:50                         353.0
# 30486         NaT        NaT                           NaN
# 43648  2025-11-10   22:13:06                         577.0
# 32247         NaT        NaT                           NaN
# 7861   2025-07-16   10:14:32                         547.0
#
#        EMS Apparatus Count Incident Number                    Incident Type  \
# 51745                  0.0         2524589      Outside rubbish fire, other
# 30486                  NaN             NaN                              NaN
# 43648                  0.0         2536164         Carbon monoxide incident
# 32247                  NaN             NaN                              NaN
# 7861                   0.0         2522427  Medical assist, assist EMS crew
#
#              Incident Type Group   Latitude  Longitude    Shift      Station  \
# 51745                 100 - Fire  36.005684 -78.903297  C Shift  CAD Beat 01
# 30486                        NaN        NaN        NaN      NaN          NaN
# 43648  400 - Hazardous Condition  36.009315 -78.944962  A Shift  CAD Beat 02
# 32247                        NaN        NaN        NaN      NaN          NaN
# 7861          300 - Rescue & EMS   0.000000   0.000000  B Shift  CAD Beat 03
#
#        Suppression Apparatus Count  Total On Scene Time  \
# 51745                          6.0                765.0
# 30486                          NaN                  NaN
# 43648                         12.0              13870.0
# 32247                          NaN                  NaN
# 7861                           1.0               1424.0
#
#        Total Time Alarm to Last Unit Cleared                Apparatus Type
# 51745                                  907.0             Chief officer car
# 30486                                    NaN                   HazMat unit
# 43648                                14383.0                        Engine
# 32247                                    NaN                        Engine
# 7861                                  1971.0  Medical & rescue unit, other

# %% [markdown]
# #### Coverting Time to Decimal Minutes

# %%
df["Dispatch Total Response Time (min)"] = df["Dispatch Total Response Time"] / 60
df["Total On Scene Time (min)"] = df["Total On Scene Time"] / 60
df["Total Time Alarm to Last Unit Cleared (min)"] = df["Total Time Alarm to Last Unit Cleared"] / 60

# Dropping original columns
df = df.drop(columns=["Dispatch Total Response Time"])
df = df.drop(columns=["Total On Scene Time"])
df = df.drop(columns=["Total Time Alarm to Last Unit Cleared"])
display(df.sample(5))
# Out:
#        Alarm Date Alarm Time  EMS Apparatus Count Incident Number  \
# 15137  2026-04-05   21:04:57                  0.0         2610590
# 386           NaT        NaT                  NaN             NaN
# 8115          NaT        NaT                  NaN             NaN
# 11076  2025-10-15   03:18:01                  0.0         2532939
# 47837  2025-06-01   15:32:08                  0.0         2517159
#
#                                           Incident Type  \
# 15137        Carbon monoxide detector activation, no CO
# 386                                                 NaN
# 8115                                                NaN
# 11076                    Dispatched & canceled en route
# 47837  EMS call, excluding vehicle accident with injury
#
#           Incident Type Group   Latitude  Longitude    Shift      Station  \
# 15137       700 - False Alarm  35.926739 -78.765358  A Shift        FS 17
# 386                       NaN        NaN        NaN      NaN          NaN
# 8115                      NaN        NaN        NaN      NaN          NaN
# 11076  600 - Good Intent Call  35.996002 -78.905853  B Shift  CAD Beat 01
# 47837      300 - Rescue & EMS   0.000000   0.000000  B Shift  CAD Beat 03
#
#        Suppression Apparatus Count                Apparatus Type  \
# 15137                          1.0                        Engine
# 386                            NaN      Other apparatus/resource
# 8115                           NaN      Other apparatus/resource
# 11076                          2.0  Medical & rescue unit, other
# 47837                          1.0                        Engine
#
#        Dispatch Total Response Time (min)  Total On Scene Time (min)  \
# 15137                            7.733333                   4.800000
# 386                                   NaN                        NaN
# 8115                                  NaN                        NaN
# 11076                                 NaN                        NaN
# 47837                            2.700000                   7.833333
#
#        Total Time Alarm to Last Unit Cleared (min)
# 15137                                    10.433333
# 386                                            NaN
# 8115                                           NaN
# 11076                                     4.100000
# 47837                                    10.533333

# %% [markdown]
# #### Dropping "Shift" from the Shift column

# %%
df["Shift"] = df["Shift"].str.strip().str.replace("Shift", "", regex=False)
display(df.sample(5))
# Out:
#        Alarm Date Alarm Time  EMS Apparatus Count Incident Number  \
# 8081   2025-06-14   16:20:04                  0.0         2518655
# 52502         NaT        NaT                  NaN             NaN
# 36725  2025-08-06   19:43:23                  0.0         2524942
# 47672         NaT        NaT                  NaN             NaN
# 30080         NaT        NaT                  NaN             NaN
#
#                                           Incident Type  \
# 8081                     Dispatched & canceled en route
# 52502                                               NaN
# 36725  EMS call, excluding vehicle accident with injury
# 47672                                               NaN
# 30080                                               NaN
#
#           Incident Type Group  Latitude  Longitude Shift      Station  \
# 8081   600 - Good Intent Call   0.00000   0.000000    B   CAD Beat 01
# 52502                     NaN       NaN        NaN   NaN          NaN
# 36725      300 - Rescue & EMS  35.93145 -78.817329    B   CAD Beat 13
# 47672                     NaN       NaN        NaN   NaN          NaN
# 30080                     NaN       NaN        NaN   NaN          NaN
#
#        Suppression Apparatus Count                Apparatus Type  \
# 8081                           1.0                        Engine
# 52502                          NaN                        Engine
# 36725                          2.0                        Engine
# 47672                          NaN  Medical & rescue unit, other
# 30080                          NaN  Medical & rescue unit, other
#
#        Dispatch Total Response Time (min)  Total On Scene Time (min)  \
# 8081                                  NaN                        NaN
# 52502                                 NaN                        NaN
# 36725                                7.25                  16.866667
# 47672                                 NaN                        NaN
# 30080                                 NaN                        NaN
#
#        Total Time Alarm to Last Unit Cleared (min)
# 8081                                      1.700000
# 52502                                          NaN
# 36725                                    23.783333
# 47672                                          NaN
# 30080                                          NaN

# %% [markdown]
# #### Dropping "FS" and "CAD Beat" from Station Column and any zero in front of the number e.g in 05

# %%
df["Station"] = (
    df["Station"]
    .astype(str)
    .str.strip()
    .str.replace("FS", "", regex=False)
    .str.replace("CAD Beat", "", regex=False)
    .str.replace(r"[^\d]", "", regex=True)   # keeping only digits
)

# Converting to numeric and force integer
df["Station"] = pd.to_numeric(df["Station"], errors="coerce")
df = df.dropna(subset=["Station"])
df["Station"] = df["Station"].astype(int)

display(df.sample(5))
# Out:
#        Alarm Date Alarm Time  EMS Apparatus Count Incident Number  \
# 40095  2026-04-20   07:59:04                  0.0         2612236
# 52292  2025-10-20   12:39:24                  0.0         2533605
# 54216  2026-04-06   15:25:07                  0.0         2610677
# 58661  2026-05-11   19:36:32                  0.0         2614644
# 56620  2026-03-09   08:00:01                  0.0         2607525
#
#                                            Incident Type  \
# 40095   EMS call, excluding vehicle accident with injury
# 52292  Smoke detector activation, no fire - unintenti...
# 54216                    Medical assist, assist EMS crew
# 58661   No incident found on arrival at dispatch address
# 56620                                  Citizen complaint
#
#           Incident Type Group   Latitude  Longitude Shift  Station  \
# 40095      300 - Rescue & EMS  36.046665 -78.889595    A         7
# 52292       700 - False Alarm  35.950329 -78.934402    B         6
# 54216      300 - Rescue & EMS  35.972515 -78.888008    C         4
# 58661  600 - Good Intent Call  35.895199 -78.873573    A        19
# 56620  900 - Special Incident  36.012165 -78.892487    C         1
#
#        Suppression Apparatus Count                Apparatus Type  \
# 40095                          1.0                        Engine
# 52292                          2.0               Truck or aerial
# 54216                          1.0                        Engine
# 58661                          2.0  Medical & rescue unit, other
# 56620                          2.0                        Engine
#
#        Dispatch Total Response Time (min)  Total On Scene Time (min)  \
# 40095                            8.600000                  20.666667
# 52292                            5.883333                   2.883333
# 54216                            5.133333                   7.833333
# 58661                            7.166667                   4.100000
# 56620                            6.100000                  10.150000
#
#        Total Time Alarm to Last Unit Cleared (min)
# 40095                                    29.083333
# 52292                                     7.466667
# 54216                                    12.816667
# 58661                                     8.316667
# 56620                                    11.816667

# %% [markdown]
# #### Filtering out Stations that not Stations 1-19

# %%
# Converting Station to numeric (invalid values become NaN)
df["Station"] = pd.to_numeric(df["Station"], errors="coerce")

# Keeping only stations 1–19
df = df[df["Station"].between(1, 19)]

display(df.sample(5))

print("June rows:", pd.to_datetime(df["Alarm Date"], errors="coerce").dt.month.eq(6).sum())
# Out:
#        Alarm Date Alarm Time  EMS Apparatus Count Incident Number  \
# 23008  2025-06-22   10:08:03                  0.0         2519504
# 3433   2025-11-20   01:30:25                  0.0         2537287
# 22388  2025-07-27   15:58:44                  0.0         2523745
# 48690  2025-08-08   13:37:44                  0.0         2525147
# 30781  2025-11-01   06:01:45                  0.0         2535038
#
#                                           Incident Type Incident Type Group  \
# 23008                  False alarm or false call, other   700 - False Alarm
# 3433                    Medical assist, assist EMS crew  300 - Rescue & EMS
# 22388  EMS call, excluding vehicle accident with injury  300 - Rescue & EMS
# 48690                   Medical assist, assist EMS crew  300 - Rescue & EMS
# 30781  EMS call, excluding vehicle accident with injury  300 - Rescue & EMS
#
#         Latitude  Longitude Shift  Station  Suppression Apparatus Count  \
# 23008   0.000000   0.000000    B         6                          2.0
# 3433   35.975437 -78.889206    B         4                          2.0
# 22388   0.000000   0.000000    C        11                          2.0
# 48690  35.900204 -78.899597    A        12                          1.0
# 30781  36.047665 -78.840088    B         1                          1.0
#
#                      Apparatus Type  Dispatch Total Response Time (min)  \
# 23008                        Engine                            4.766667
# 3433   Medical & rescue unit, other                            8.600000
# 22388                         Quint                            4.500000
# 48690               Truck or aerial                            7.350000
# 30781                        Engine                            6.450000
#
#        Total On Scene Time (min)  Total Time Alarm to Last Unit Cleared (min)
# 23008                  34.683333                                    39.450000
# 3433                   40.200000                                    48.666667
# 22388                   7.583333                                    12.083333
# 48690                   6.116667                                    12.866667
# 30781                  27.983333                                    34.000000
# June rows: 2994

# %% [markdown]
# #### Adding Battalion Column

# %%
# Battalion mapping
battalion_map = {
    "1": 1,
    "2": 1,
    "3": 4,
    "4": 1,
    "5": 1,
    "6": 3,
    "7": 2,
    "8": 4,
    "9": 4,
    "10": 2,
    "11": 1,
    "12": 3,
    "13": 4,
    "14": 2,
    "15": 2,
    "16": 3,
    "17": 4,
    "18": 3,
    "19": 3
}

# Adding Battalion column
df["Battalion"] = df["Station"].astype(str).map(battalion_map)

display(df.sample(5))

print("June rows:", pd.to_datetime(df["Alarm Date"], errors="coerce").dt.month.eq(6).sum())
# Out:
#        Alarm Date Alarm Time  EMS Apparatus Count Incident Number  \
# 42542  2026-04-24   09:31:12                  0.0         2612704
# 44251  2025-06-30   19:34:41                  0.0         2520586
# 26308  2026-01-21   22:41:53                  0.0         2602436
# 41573  2025-10-10   10:03:50                  0.0         2532391
# 19324  2026-02-27   12:21:46                  0.0         2606474
#
#                                           Incident Type Incident Type Group  \
# 42542  Alarm system activation, no fire - unintentional   700 - False Alarm
# 44251  Alarm system activation, no fire - unintentional   700 - False Alarm
# 26308                         Person in distress, other  500 - Service Call
# 41573                             Rescue or EMS standby  300 - Rescue & EMS
# 19324           Alarm system sounded due to malfunction   700 - False Alarm
#
#         Latitude  Longitude Shift  Station  Suppression Apparatus Count  \
# 42542  35.965412 -78.911049    A         4                          2.0
# 44251   0.000000   0.000000    A         4                          2.0
# 26308  35.900204 -78.899597    C        12                          1.0
# 41573  35.940601 -78.992104    C        16                          2.0
# 19324  36.095276 -78.917076    A        14                          2.0
#
#         Apparatus Type  Dispatch Total Response Time (min)  \
# 42542  Truck or aerial                            5.216667
# 44251           Engine                            4.783333
# 26308           Engine                            9.500000
# 41573            Quint                            9.766667
# 19324  Truck or aerial                           10.066667
#
#        Total On Scene Time (min)  Total Time Alarm to Last Unit Cleared (min)  \
# 42542                   4.700000                                     8.066667
# 44251                   8.683333                                    13.466667
# 26308                  23.716667                                    29.700000
# 41573                   2.933333                                    11.916667
# 19324                   9.300000                                    18.433333
#
#        Battalion
# 42542          1
# 44251          1
# 26308          3
# 41573          3
# 19324          2
# June rows: 2994

# %% [markdown]
# #### Dropping blank rows of Apparatus Type

# %%
# Dropping rows where Apparatus Type is blank or null
df = df[
    df["Apparatus Type"].notna() &
    (df["Apparatus Type"].astype(str).str.strip() != "")
]

display(df.sample(5))

print("June rows:", pd.to_datetime(df["Alarm Date"], errors="coerce").dt.month.eq(6).sum())
# Out:
#        Alarm Date Alarm Time  EMS Apparatus Count Incident Number  \
# 37961  2026-02-10   16:30:34                  0.0         2604585
# 49236  2026-05-20   17:26:59                  0.0         2615642
# 47911  2025-11-15   11:57:51                  0.0         2536729
# 23150  2025-10-25   23:55:59                  0.0         2534304
# 24279  2025-07-06   19:26:51                  0.0         2521280
#
#                                            Incident Type  \
# 37961   EMS call, excluding vehicle accident with injury
# 49236           HazMat release investigation w/no HazMat
# 47911  Smoke detector activation, no fire - unintenti...
# 23150                    Medical assist, assist EMS crew
# 24279   EMS call, excluding vehicle accident with injury
#
#           Incident Type Group   Latitude  Longitude Shift  Station  \
# 37961      300 - Rescue & EMS  35.987007 -78.900589    A         1
# 49236  600 - Good Intent Call  35.965958 -78.948914    A         5
# 47911       700 - False Alarm  35.894119 -78.920609    B        18
# 23150      300 - Rescue & EMS  36.035164 -78.907822    C         7
# 24279      300 - Rescue & EMS   0.000000   0.000000    C         1
#
#        Suppression Apparatus Count                Apparatus Type  \
# 37961                          3.0             Chief officer car
# 49236                          3.0                   HazMat unit
# 47911                          2.0               Truck or aerial
# 23150                          1.0  Medical & rescue unit, other
# 24279                          1.0  Medical & rescue unit, other
#
#        Dispatch Total Response Time (min)  Total On Scene Time (min)  \
# 37961                            3.433333                  34.216667
# 49236                           15.733333                  11.300000
# 47911                            5.150000                   2.883333
# 23150                            4.533333                  12.216667
# 24279                            6.066667                  21.000000
#
#        Total Time Alarm to Last Unit Cleared (min)  Battalion
# 37961                                    37.450000          1
# 49236                                    25.516667          1
# 47911                                     5.466667          3
# 23150                                    16.616667          2
# 24279                                    27.066667          1
# June rows: 2991

# %% [markdown]
# #### Exporting File to Output Folder

# %%
# Ensuring output folder exists
os.makedirs("output", exist_ok=True)

# Exporting cleaned dataframe
file_path = "C:/Users/AmarachiOny/Desktop/DFD_Projects/Python/Compass_ESO_Data/output/Compass_Data_1_Cleaned.csv"
df.to_csv(file_path, index=False)

print("Export successful: Compass_Data_1_Cleaned.csv has been created in the output folder.")
# Out:
# Export successful: Compass_Data_1_Cleaned.csv has been created in the output folder.
